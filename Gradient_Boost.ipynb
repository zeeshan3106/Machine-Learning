# %% [markdown]
# <a href="https://colab.research.google.com/github/zeeshan3106/Machine-Learning/blob/main/Gradient_Boost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv("australian_property_regression.csv")
data
X = data[['Distance_to_CBD_KM','Floor_Area_SqM','Bedroom_Count','Property_Value_AUD_K']]
data
y = data['Property_Value_AUD_K']
X['pred_1'] = X['Property_Value_AUD_K'].mean()
X
# Out:
# /tmp/ipykernel_2350/144627171.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['pred_1'] = X['Property_Value_AUD_K'].mean()
#     Distance_to_CBD_KM  Floor_Area_SqM  Bedroom_Count  Property_Value_AUD_K  \
# 0                 10.3            59.0              2                 665.3
# 1                 23.8           241.0              3                1152.6
# 2                 18.7           144.0              4                 916.3
# 3                 15.6           203.0              2                 998.5
# 4                  5.2           322.0              2                1579.5
# ..                 ...             ...            ...                   ...
# ...

# %%
X.sample(2)
# Out:
#     Distance_to_CBD_KM  Floor_Area_SqM  Bedroom_Count  Property_Value_AUD_K  \
# 73                20.7           118.0              2                 751.0
# 71                 6.2            55.0              3                 792.0
#
#       pred_1
# 73  1082.304
# 71  1082.304

# %%
X['pred_1'] = X['Property_Value_AUD_K'].mean()
y = X['pred_1']

X['Loss_1'] = X['Property_Value_AUD_K'] - X['pred_1']
X.sample(2)
X2 = X[['Distance_to_CBD_KM','Floor_Area_SqM','Bedroom_Count']]
X2
y2 = X['Loss_1']
y2
# Out:
# /tmp/ipykernel_2350/3320678542.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['pred_1'] = X['Property_Value_AUD_K'].mean()
# 0    -417.004
# 1      70.296
# 2    -166.004
# 3     -83.804
# 4     497.196
#        ...
# 95   -128.104
# 96    210.696
# 97    292.296
# 98    466.396
# 99    393.396
# Name: Loss_1, Length: 100, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor
tree = DecisionTreeRegressor(max_leaf_nodes=8)
training = tree.fit(X2,y2)
pred = tree.predict(X2)
pred2 = pd.DataFrame(pred)
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y2, pred)
X2['Loss_1']= X['Loss_1']
X2['pred_2'] = pred2

X2['Loss_2']=X2['Loss_1']-X2['pred_2']
X2
# Out:
# /tmp/ipykernel_2350/4104876679.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X2['Loss_1']= X['Loss_1']
# /tmp/ipykernel_2350/4104876679.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X2['pred_2'] = pred2
#     Distance_to_CBD_KM  Floor_Area_SqM  Bedroom_Count   Loss_1      pred_2  \
# 0                 10.3            59.0              2 -417.004 -377.592889
# 1                 23.8           241.0              3   70.296  -89.379000
# ...

# %%
X3 = X2[['Distance_to_CBD_KM','Floor_Area_SqM','Bedroom_Count']]
X3
y3 = X2['Loss_2']
y3
# Out:
# 0     -39.411111
# 1     159.675000
# 2      89.788235
# 3    -193.372222
# 4      90.815789
#          ...
# 95    127.688235
# 96    -44.963636
# 97   -114.084211
# 98     60.015789
# 99    -12.984211
# Name: Loss_2, Length: 100, dtype: float64

# %%
from sklearn.tree import DecisionTreeRegressor
tree = DecisionTreeRegressor(max_leaf_nodes=32)
training = tree.fit(X3,y3)
pred = tree.predict(X3)
pred3 = pd.DataFrame(pred)
# from sklearn.metrics import mean_absolute_error
# mean_absolute_error(y2, pred3)
pred3
X3['Loss_3']= X2['Loss_2']
X3['pred_3'] = pred3
X3
# Out:
# /tmp/ipykernel_2350/2102961034.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X3['Loss_3']= X2['Loss_2']
# /tmp/ipykernel_2350/2102961034.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X3['pred_3'] = pred3
#     Distance_to_CBD_KM  Floor_Area_SqM  Bedroom_Count      Loss_3      pred_3
# 0                 10.3            59.0              2  -39.411111  -75.005625
# 1                 23.8           241.0              3  159.675000   79.671959
# ...

# %%
Combine = 1082+(406.380211)+(65.404094)
Final={}
Final=  pd.DataFrame([Combine],columns=['Combined_Prediction'])

Final['Actual_Price']=1548.7
Final
# Out:
#    Combined_Prediction  Actual_Price
# 0          1553.784305        1548.7
