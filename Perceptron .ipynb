# %% [markdown]
# <a href="https://colab.research.google.com/github/zeeshan3106/Machine-Learning/blob/main/Perceptron%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv("CGPAIq.csv")
X = data.drop('Placed', axis=1)
y = data['Placed']
data.head(2)
# Out:
#    CGPA   IQ  Placed
# 0  2.75   91       0
# 1  3.90  115       1

# %%
sns.scatterplot(x = data['CGPA'],y = data['IQ'],hue=data['Placed'])
# Out:
# <Axes: xlabel='CGPA', ylabel='IQ'>

# %%
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score
p = Perceptron()
p.fit(X,y)
p.coef_
p.intercept_
a = p.predict(X)
accuracy_score(a,y)*100
# Out:
# 77.83505154639175

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X.values, y.values, clf=p, legend=2)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
